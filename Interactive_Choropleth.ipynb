# %%
import pandas as pd

# %%
df1 = pd.read_csv("data.csv")

# %%
df1
# Out:
#                    state  id  population  engineers  hurricanes
# 0                Alabama   1     4863300   0.003422          22
# 1                 Alaska   2      741894   0.001591           0
# 2                Arizona   4     6931071   0.004774           0
# 3               Arkansas   5     2988248   0.002440           0
# 4             California   6    39250017   0.007126           0
# 5               Colorado   8     5540545   0.008088           0
# 6            Connecticut   9     3576452   0.005897          10
# 7               Delaware  10      952065   0.004989           2
# 8   District of Columbia  11      681170   0.011759           0
# 9                Florida  12    20612439   0.003300         110
# 10               Georgia  13    10310371   0.004940          20
# 11                Hawaii  15     1428557   0.001624           0
# 12                 Idaho  16     1683140   0.002971           0
# 13              Illinois  17    12801539   0.004478           0
# ...

# %%
df2 = pd.read_csv('pops2.csv')

# %%
df2
# Out:
#                     State Alabama Alaska Arizona Arkansas California Colorado  \
# 0                 Alabama       -    260    1750      636       3310     3422
# 1                  Alaska    1105      -    1561       98       5064      862
# 2                 Arizona     904    886       -      692      28226    10616
# 3                Arkansas     813     12    1022        -       3104     1022
# 4              California    3690   2547   59713     4967          -    29350
# 5                Colorado    2042    685   14684     1585      15085        -
# 6             Connecticut     705    153     895       87       4067      942
# 7                Delaware       0    224     653        0       1630        0
# 8   District of Columbia      248     69     239      295       3075      259
# 9                 Florida   15519   2473    7358     2118      22692    14124
# 10                Georgia   13993    743    3947     1352      14496     6985
# ...

# %%
df = df1.merge(df2, right_on='State', left_on='state')

# %%
df['Select State Here'] = 0

# %%
df.to_csv("test.csv")

# %%
import altair as alt
from vega_datasets import data
import panel as pn

pn.extension('vega')

# %%
# !pip install panel

# %%
states = alt.topo_feature(data.us_10m.url, 'states')
states['url'] = 'https://raw.githubusercontent.com/vega/vega/master/docs/data/us-10m.json'
source = 'test.csv'
variable_list = ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia ', 'Florida','Georgia', 'Hawaii','Idaho','Illinois','Indiana','Iowa','Kansas','Kentucky','Louisiana','Maine','Maryland','Massachusetts','Michigan','Minnesota','Mississippi','Missouri','Montana','Nebraska','Nevada','New Hampshire','New Jersey','New Mexico','New York','North Carolina','North Dakota','Ohio','Oklahoma','Oregon','Pennsylvania','Rhode Island','South Carolina','South Dakota','Tennessee','Texas','Utah','Vermont','Virginia','Washington','West Virginia','Wisconsin','Wyoming','Puerto Rico']

variable = pn.widgets.Select(options=variable_list, name='Variable')

@pn.depends(variable.param.value)
def get_map(variable):
    return alt.Chart(states).mark_geoshape().encode(
        alt.Color(variable, type='quantitative')
    ).transform_lookup(
        lookup='id',
        from_=alt.LookupData(source, 'id', [variable])
    ).properties(
        width=500,
        height=300
    ).project(
        type='albersUsa'
    ).repeat(
        row=[variable]
    )

pn.Row(
    pn.Column('# Where are people in your state moving?', '<i>Number of inter-state migrants in 2019</i>', variable),
    get_map
).servable()
# Out:
# Row
#     [0] Column
#         [0] Markdown(str)
#         [1] Markdown(str)
#         [2] Select(name='Variable', options=['Alabama', 'Alaska', ...], value='Alabama')
#     [1] ParamFunction(function)

# %%
states = alt.topo_feature(data.us_10m.url, 'states')
states['url'] = 'https://raw.githubusercontent.com/vega/vega/master/docs/data/us-10m.json'
source = 'test.csv'
variable_list = ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia ', 'Florida','Georgia', 'Hawaii','Idaho','Illinois','Indiana','Iowa','Kansas','Kentucky','Louisiana','Maine','Maryland','Massachusetts','Michigan','Minnesota','Mississippi','Missouri','Montana','Nebraska','Nevada','New Hampshire','New Jersey','New Mexico','New York','North Carolina','North Dakota','Ohio','Oklahoma','Oregon','Pennsylvania','Rhode Island','South Carolina','South Dakota','Tennessee','Texas','Utah','Vermont','Virginia','Washington','West Virginia','Wisconsin','Wyoming','Puerto Rico']

variable = pn.widgets.Select(options=variable_list, name='Variable')

@pn.depends(variable.param.value)
def get_map(variable):
    return alt.Chart(states).mark_geoshape().encode(
        alt.Color(variable, type='quantitative')
    ).transform_lookup(
        lookup='id',
        from_=alt.LookupData(source, 'id', [variable])
    ).properties(
        width=500,
        height=300
    ).project(
        type='albersUsa'
    ).repeat(
        row=[variable]
    )

test = pn.Row(
    pn.Column('# Where are people in your state moving?', '<i>Number of inter-state migrants in 2019</i>', variable),
    get_map
).servable()

# %%
save(test, paneltest.html, title=None, resources=None, template=None,
         template_variables=None, embed=False, max_states=1000,
         max_opts=3, embed_json=False, json_prefix='', save_path='./',
         load_path=None)test
# Out:
#   File "<ipython-input-57-ba6b8afac967>", line 4
#     load_path=None)test
#                    ^
# SyntaxError: invalid syntax

# %%
test
# Out:
# Row
#     [0] Column
#         [0] Markdown(str)
#         [1] Markdown(str)
#         [2] Select(name='Variable', options=['Alabama', 'Alaska', ...], value='Alabama')
#     [1] ParamFunction(function)

# %%
test.embed()
# Out:
# <div id='1230'>
#
#
#
#
#
#   <div class="bk-root" id="ee6b5e9c-3823-45fc-acc2-05250c47bec5" data-root-id="1230"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
# ...

# %%
test.save('testmapchoro.html')
